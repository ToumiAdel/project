# %%
"""
====================================
Tutorial 4: Creating a dataset class
====================================
"""
# Authors: Pedro L. C. Rodrigues, Sylvain Chevallier
#
# https://github.com/plcrodrigues/Workshop-MOABB-BCI-Graz-2019

import mne
import numpy as np
from pyriemann.classification import MDM
from pyriemann.estimation import Covariances
from scipy.io import loadmat, savemat
from sklearn.pipeline import make_pipeline

from moabb.datasets import download as dl
from moabb.datasets.base import BaseDataset
from moabb.evaluations import WithinSessionEvaluation
from moabb.paradigms import LeftRightImagery

# %%
##############################################################################
# Creating some Data
# ------------------
#
# To illustrate the creation of a dataset class in MOABB, we first create an
# example dataset saved in .mat file. It contains a single fake recording on
# 8 channels lasting for 150 seconds (sampling frequency 256 Hz). We have
# included the script that creates this dataset and have uploaded it online.
# The fake dataset is available on the
# `Zenodo website <https://sandbox.zenodo.org/record/369543>`_


def create_example_dataset():
    """Create a fake example for a dataset."""
    sfreq = 256
    t_recording = 150
    t_trial = 1  # duration of a trial
    intertrial = 2  # time between end of a trial and the next one
    n_chan = 8

    x = np.zeros((n_chan + 1, t_recording * sfreq))  # electrodes + stimulus
    stim = np.zeros(t_recording * sfreq)
    t_offset = 1.0  # offset where the trials start
    n_trials = 40

    rep = np.linspace(0, 4 * t_trial, t_trial * sfreq)
    signal = np.sin(2 * np.pi / t_trial * rep)
    for n in range(n_trials):
        label = n % 2 + 1  # alternate between class 0 and class 1
        tn = int(t_offset * sfreq + n * (t_trial + intertrial) * sfreq)
        stim[tn] = label
        noise = 0.1 * np.random.randn(n_chan, len(signal))
        x[:-1, tn : (tn + t_trial * sfreq)] = label * signal + noise
    x[-1, :] = stim
    return x, sfreq


# Create the fake data
for subject in [1, 2, 3]:
    x, fs = create_example_dataset()
    filename = "subject_" + str(subject).zfill(2) + ".mat"
    mdict = {}
    mdict["x"] = x
    mdict["fs"] = fs
    savemat(filename, mdict)

# %%
##############################################################################
# Creating a Dataset Class
# ------------------------
#
# We will create now a dataset class using the fake data simulated with the
# code from above. For this, we first need to import the right classes from
# MOABB:
#
# - ``dl`` is a very useful script that downloads automatically a dataset online
#   if it is not yet available in the user's computer. The script knows where
#   to download the files because we create a global variable telling the URL
#   where to fetch the data.
# - ``BaseDataset`` is the basic class that we overload to create our dataset.
#
# The global variable with the dataset's URL should specify an online
# repository where all the files are stored.

ExampleDataset_URL = "https://sandbox.zenodo.org/record/369543/files/"


##############################################################################
# The ``ExampleDataset`` needs to implement only 3 functions:
#
# - ``__init__`` for indicating the parameter of the dataset
# - ``_get_single_subject_data`` to define how to process the data once they
#   have been downloaded
# - ``data_path`` to define how the data are downloaded.


class ExampleDataset(BaseDataset):
    """Dataset used to exemplify the creation of a dataset class in MOABB.

    The data samples have been simulated and has no physiological
    meaning whatsoever.
    """

    def __init__(self):
        super().__init__(
            subjects=[1, 2, 3],
            sessions_per_subject=1,
            events={"left_hand": 1, "right_hand": 2},
            code="ExampleDataset",
            interval=[0, 0.75],
            paradigm="imagery",
            doi="",
        )

    def _get_single_subject_data(self, subject):
        """Return data for a single subject."""
        file_path_list = self.data_path(subject)

        data = loadmat(file_path_list[0])
        x = data["x"]
        fs = data["fs"]
        ch_names = ["ch" + str(i) for i in range(8)] + ["stim"]
        ch_types = ["eeg" for i in range(8)] + ["stim"]
        info = mne.create_info(ch_names, fs, ch_types)
        raw = mne.io.RawArray(x, info)

        sessions = {}
        sessions["0"] = {}
        sessions["0"]["0"] = raw
        return sessions

    def data_path(
        self, subject, path=None, force_update=False, update_path=None, verbose=None
    ):
        """Download the data from one subject."""
        if subject not in self.subject_list:
            raise (ValueError("Invalid subject number"))

        url = "{:s}subject_0{:d}.mat".format(ExampleDataset_URL, subject)
        path = dl.data_dl(url, "ExampleDataset")
        return [path]  # it has to return a list

# %%
##############################################################################
# Using the ExampleDataset
# ------------------------
#
# Now that the `ExampleDataset` is defined, it could be instantiated directly.
# The rest of the code follows the steps described in the previous tutorials.

dataset = ExampleDataset()

paradigm = LeftRightImagery()
X, labels, meta = paradigm.get_data(dataset=dataset, subjects=[1])

evaluation = WithinSessionEvaluation(
    paradigm=paradigm, datasets=dataset, overwrite=False, suffix="newdataset"
)
pipelines = {}
pipelines["MDM"] = make_pipeline(Covariances("oas"), MDM(metric="riemann"))
scores = evaluation.process(pipelines)

print(scores)
# Out:
# Downloading data from 'https://sandbox.zenodo.org/record/369543/files/subject_01.mat' to file 'C:\Users\ABC\mne_data\MNE-exampledataset-data\record\369543\files\subject_01.mat'.
# c:\Users\ABC\anaconda3\envs\py38\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sandbox.zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\ABC\anaconda3\envs\py38\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sandbox.zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       8 dataset = ExampleDataset()
#      10 paradigm = LeftRightImagery()
# ---> 11 X, labels, meta = paradigm.get_data(dataset=dataset, subjects=[1])
#      13 evaluation = WithinSessionEvaluation(
#      14     paradigm=paradigm, datasets=dataset, overwrite=False, suffix="newdataset"
#      15 )
#      16 pipelines = {}
#
# File c:\Users\ABC\anaconda3\envs\py38\lib\site-packages\moabb\paradigms\base.py:278, in BaseProcessing.get_data(self, dataset, subjects, return_epochs, return_raws, cache_config, postprocess_pipeline)
#     273 process_pipelines = self.make_process_pipelines(
#     274     dataset, return_epochs, return_raws, postprocess_pipeline
#     275 )
#     276 labels_pipeline = self.make_labels_pipeline(dataset, return_epochs, return_raws)
# --> 278 data = [
#     279     dataset.get_data(
#     280         subjects=subjects,
#     281         cache_config=cache_config,
#     282         process_pipeline=process_pipeline,
#     283     )
#     284     for process_pipeline in process_pipelines
#     285 ]
#     287 X = []
#     288 labels = []
#
# File c:\Users\ABC\anaconda3\envs\py38\lib\site-packages\moabb\paradigms\base.py:279, in <listcomp>(.0)
#     273 process_pipelines = self.make_process_pipelines(
#     274     dataset, return_epochs, return_raws, postprocess_pipeline
#     275 )
#     276 labels_pipeline = self.make_labels_pipeline(dataset, return_epochs, return_raws)
#     278 data = [
# --> 279     dataset.get_data(
#     280         subjects=subjects,
#     281         cache_config=cache_config,
#     282         process_pipeline=process_pipeline,
#     283     )
#     284     for process_pipeline in process_pipelines
#     285 ]
#     287 X = []
#     288 labels = []
#
# File c:\Users\ABC\anaconda3\envs\py38\lib\site-packages\moabb\datasets\base.py:342, in BaseDataset.get_data(self, subjects, cache_config, process_pipeline)
#     340     if subject not in self.subject_list:
#     341         raise ValueError("Invalid subject {:d} given".format(subject))
# --> 342     data[subject] = self._get_single_subject_data_using_cache(
#     343         subject,
#     344         cache_config,
#     345         process_pipeline,
#     346     )
#     347 check_subject_names(data)
#     348 check_session_names(data)
#
# File c:\Users\ABC\anaconda3\envs\py38\lib\site-packages\moabb\datasets\base.py:436, in BaseDataset._get_single_subject_data_using_cache(self, subject, cache_config, process_pipeline)
#     434 # Load and eventually overwrite:
#     435 if len(cached_steps) == 0:  # last option: we don't use cache
# --> 436     sessions_data = self._get_single_subject_data(subject)
#     437     assert sessions_data is not None  # should not happen
#     438 else:
#
# Cell In[6], line 50, in ExampleDataset._get_single_subject_data(self, subject)
#      48 def _get_single_subject_data(self, subject):
#      49     """Return data for a single subject."""
# ---> 50     file_path_list = self.data_path(subject)
#      52     data = loadmat(file_path_list[0])
#      53     x = data["x"]
#
# Cell In[6], line 73, in ExampleDataset.data_path(self, subject, path, force_update, update_path, verbose)
#      70     raise (ValueError("Invalid subject number"))
#      72 url = "{:s}subject_0{:d}.mat".format(ExampleDataset_URL, subject)
# ---> 73 path = dl.data_dl(url, "ExampleDataset")
#      74 return [path]
#
# File <decorator-gen-432>:12, in data_dl(url, sign, path, force_update, verbose)
#
# File c:\Users\ABC\anaconda3\envs\py38\lib\site-packages\moabb\datasets\download.py:155, in data_dl(url, sign, path, force_update, verbose)
#     153 else:
#     154     known_hash = file_hash(str(destination))
# --> 155 dlpath = retrieve(
#     156     url,
#     157     known_hash,
#     158     fname=Path(url).name,
#     159     path=str(destination.parent),
#     160     progressbar=True,
#     161     downloader=downloader,
#     162 )
#     163 return dlpath
#
# File c:\Users\ABC\anaconda3\envs\py38\lib\site-packages\pooch\core.py:239, in retrieve(url, known_hash, fname, path, processor, downloader, progressbar)
#     236 if downloader is None:
#     237     downloader = choose_downloader(url, progressbar=progressbar)
# --> 239 stream_download(url, full_path, known_hash, downloader, pooch=None)
#     241 if known_hash is None:
#     242     get_logger().info(
#     243         "SHA256 hash of downloaded file: %s\n"
#     244         "Use this value as the 'known_hash' argument of 'pooch.retrieve'"
#    (...)
#     247         file_hash(str(full_path)),
#     248     )
#
# File c:\Users\ABC\anaconda3\envs\py38\lib\site-packages\pooch\core.py:807, in stream_download(url, fname, known_hash, downloader, pooch, retry_if_failed)
#     805         shutil.move(tmp, str(fname))
#     806     break
# --> 807 except (ValueError, requests.exceptions.RequestException):
#     808     if i == download_attempts - 1:
#     809         raise
#
# File c:\Users\ABC\anaconda3\envs\py38\lib\site-packages\pooch\downloaders.py:215, in __call__(self, url, output_file, pooch, check_only)
#     210 if self.progressbar is True:
#     211     # Need to use ascii characters on Windows because there isn't
#     212     # always full unicode support
#     213     # (see https://github.com/tqdm/tqdm/issues/454)
#     214     use_ascii = bool(sys.platform == "win32")
# --> 215     progress = tqdm(
#     216         total=total,
#     217         ncols=79,
#     218         ascii=use_ascii,
#     219         unit="B",
#     220         unit_scale=True,
#     221         leave=True,
#     222     )
#     223 elif self.progressbar:
#     224     progress = self.progressbar
#
# File c:\Users\ABC\anaconda3\envs\py38\lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://sandbox.zenodo.org/records/369543/files/subject_01.mat
