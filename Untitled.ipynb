# %%
pip install pandas matplotlib seaborn mne scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (1.5.3)
# Requirement already satisfied: matplotlib in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (3.7.5)
# Requirement already satisfied: seaborn in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (0.12.2)
# Requirement already satisfied: mne in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (1.6.1)
# Requirement already satisfied: scikit-learn in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: scipy>=1.7.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne) (1.10.1)
# Requirement already satisfied: tqdm in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne) (4.66.2)
# Requirement already satisfied: pooch>=1.5 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne) (1.8.1)
# Requirement already satisfied: decorator in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne) (5.1.1)
# Requirement already satisfied: jinja2 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne) (3.1.3)
# Requirement already satisfied: lazy-loader>=0.3 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne) (0.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from scikit-learn) (3.3.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from pooch>=1.5->mne) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from pooch>=1.5->mne) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from jinja2->mne) (2.1.3)
# Requirement already satisfied: colorama in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from tqdm->mne) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install moabb
# Out:
# Requirement already satisfied: moabb in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (1.0.0)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (6.0.1)
# Requirement already satisfied: coverage<8.0.0,>=7.0.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (7.4.3)
# Requirement already satisfied: edflib-python<2.0.0,>=1.0.6 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (1.0.8)
# Requirement already satisfied: h5py<=3.8.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (3.8.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.6.2 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (3.7.5)
# Requirement already satisfied: memory-profiler<0.62.0,>=0.61.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (0.61.0)
# Requirement already satisfied: mne<2.0,>=1.4 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (1.6.1)
# Requirement already satisfied: mne-bids<0.14,>=0.13 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (0.13)
# Requirement already satisfied: numpy<2.0,>=1.22 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (1.24.3)
# Requirement already satisfied: pandas<2.0.0,>=1.5.2 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (1.5.3)
# Requirement already satisfied: pooch<2.0.0,>=1.6.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (1.8.1)
# Requirement already satisfied: pyriemann<0.6,>=0.5 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (0.5)
# Requirement already satisfied: pytest<8.0.0,>=7.4.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (7.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (2.31.0)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (1.3.2)
# Requirement already satisfied: scipy<2.0.0,>=1.9.3 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (1.10.1)
# Requirement already satisfied: seaborn<0.13.0,>=0.12.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (0.12.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (4.66.2)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.15 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from moabb) (1.26.18)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (6.1.1)
# Requirement already satisfied: psutil in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from memory-profiler<0.62.0,>=0.61.0->moabb) (5.9.0)
# Requirement already satisfied: decorator in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne<2.0,>=1.4->moabb) (5.1.1)
# Requirement already satisfied: jinja2 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne<2.0,>=1.4->moabb) (3.1.3)
# Requirement already satisfied: lazy-loader>=0.3 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne<2.0,>=1.4->moabb) (0.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from pandas<2.0.0,>=1.5.2->moabb) (2023.3.post1)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from pooch<2.0.0,>=1.6.0->moabb) (3.10.0)
# Requirement already satisfied: joblib in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from pyriemann<0.6,>=0.5->moabb) (1.3.2)
# Requirement already satisfied: iniconfig in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from pytest<8.0.0,>=7.4.0->moabb) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from pytest<8.0.0,>=7.4.0->moabb) (1.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from pytest<8.0.0,>=7.4.0->moabb) (1.2.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from pytest<8.0.0,>=7.4.0->moabb) (2.0.1)
# Requirement already satisfied: colorama in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from pytest<8.0.0,>=7.4.0->moabb) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from requests<3.0.0,>=2.28.1->moabb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from requests<3.0.0,>=2.28.1->moabb) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from requests<3.0.0,>=2.28.1->moabb) (2024.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from scikit-learn<2.0.0,>=1.2.0->moabb) (3.3.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib<4.0.0,>=3.6.2->moabb) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.6.2->moabb) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from jinja2->mne<2.0,>=1.4->moabb) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mne
# Out:
# Requirement already satisfied: mne in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (1.6.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne) (1.24.3)
# Requirement already satisfied: scipy>=1.7.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne) (1.10.1)
# Requirement already satisfied: matplotlib>=3.5.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne) (3.7.5)
# Requirement already satisfied: tqdm in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne) (4.66.2)
# Requirement already satisfied: pooch>=1.5 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne) (1.8.1)
# Requirement already satisfied: decorator in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne) (5.1.1)
# Requirement already satisfied: packaging in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne) (23.1)
# Requirement already satisfied: jinja2 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne) (3.1.3)
# Requirement already satisfied: lazy-loader>=0.3 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne) (0.3)
# Requirement already satisfied: importlib-resources>=5.10.2 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from mne) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from importlib-resources>=5.10.2->mne) (3.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib>=3.5.0->mne) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib>=3.5.0->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib>=3.5.0->mne) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib>=3.5.0->mne) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib>=3.5.0->mne) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib>=3.5.0->mne) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from matplotlib>=3.5.0->mne) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from pooch>=1.5->mne) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from pooch>=1.5->mne) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from jinja2->mne) (2.1.3)
# Requirement already satisfied: colorama in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from tqdm->mne) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->mne) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ja_to\anaconda3\envs\mytestenv\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2024.2.2)

# %%
import warnings

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from mne.decoding import CSP
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.pipeline import make_pipeline
import mne

import moabb
from moabb.datasets import BNCI2014_001
from moabb.evaluations import WithinSessionEvaluation
from moabb.paradigms import LeftRightImagery


moabb.set_log_level("info")
warnings.filterwarnings("ignore")
# Out:
# <frozen importlib._bootstrap>:219: FutureWarning: mne.io.pick.pick_types is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# <frozen importlib._bootstrap>:219: FutureWarning: mne.io.pick.pick_channels_regexp is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# <frozen importlib._bootstrap>:219: FutureWarning: mne.io.pick.channel_type is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# To use the get_shape_from_baseconcar, InputShapeSetterEEG, BraindecodeDatasetLoaderyou need to install `braindecode`.`pip install braindecode` or Please refer to `https://braindecode.org`.
# c:\Users\ja_to\anaconda3\envs\MyTestEnv\lib\site-packages\moabb\pipelines\__init__.py:26: ModuleNotFoundError: Tensorflow is not installed. You won't be able to use these MOABB pipelines if you attempt to do so.
#   warn(

# %%
##############################################################################
# Instantiating Dataset
# ---------------------
#
# The first thing to do is to instantiate the dataset that we want to analyze.
# MOABB has a list of many different datasets, each one containing all the
# necessary information for describing them, such as the number of subjects,
# size of trials, names of classes, etc.
#
# The dataset class has methods for:
#
# - downloading its files from some online source (e.g. Zenodo)
# - importing the data from the files in whatever extension they might be
#   (like .mat, .gdf, etc.) and instantiate a Raw object from the MNE package

dataset = BNCI2014_001()
dataset.subject_list = [1, 2, 3]

# %%
##############################################################################
# Accessing EEG Recording
# -----------------------
#
# As an example, we may access the EEG recording from a given session and a
# given run as follows:

sessions = dataset.get_data(subjects=[1])

##############################################################################
# This returns a MNE Raw object that can be manipulated. This might be enough
# for some users, since the pre-processing and epoching steps can be easily
# done via MNE. However, to conduct an assessment of several classifiers on
# multiple subjects, MOABB ends up being a more appropriate option.

subject = 1
session_name = "0train"
run_name = "0"
raw = sessions[subject][session_name][run_name]

# %%
print(dataset.get_data(subjects=[1]))
# Out:
# {1: {'0train': {'0': <RawArray | 26 x 96735 (386.9 s), ~19.2 MB, data loaded>, '1': <RawArray | 26 x 96735 (386.9 s), ~19.2 MB, data loaded>, '2': <RawArray | 26 x 96735 (386.9 s), ~19.2 MB, data loaded>, '3': <RawArray | 26 x 96735 (386.9 s), ~19.2 MB, data loaded>, '4': <RawArray | 26 x 96735 (386.9 s), ~19.2 MB, data loaded>, '5': <RawArray | 26 x 96735 (386.9 s), ~19.2 MB, data loaded>}, '1test': {'0': <RawArray | 26 x 96735 (386.9 s), ~19.2 MB, data loaded>, '1': <RawArray | 26 x 96735 (386.9 s), ~19.2 MB, data loaded>, '2': <RawArray | 26 x 96735 (386.9 s), ~19.2 MB, data loaded>, '3': <RawArray | 26 x 96735 (386.9 s), ~19.2 MB, data loaded>, '4': <RawArray | 26 x 96735 (386.9 s), ~19.2 MB, data loaded>, '5': <RawArray | 26 x 96735 (386.9 s), ~19.2 MB, data loaded>}}}

# %%
print(raw.info)
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fz, FC3, FC1, FCz, FC2, FC4, C5, C3, C1, Cz, C2, C4, C6, CP3, ...
#  chs: 22 EEG, 3 EOG, 1 Stimulus
#  custom_ref_applied: False
#  dig: 25 items (3 Cardinal, 22 EEG)
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: unspecified
#  nchan: 26
#  projs: []
#  sfreq: 250.0 Hz
# >

# %%
raw.compute_psd(fmax=50).plot()
raw.plot(duration=5, n_channels=30)
# Out:
# <MNELineFigure size 1000x350 with 2 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
# set up and fit the ICA
ica = mne.preprocessing.ICA(n_components=20, random_state=97, max_iter=800)
ica.fit(raw)
ica.exclude = [1, 2]  # details on how we picked these are omitted here
ica.plot_properties(raw, picks=ica.exclude)
# Out:
# Not setting metadata
# 193 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 193 matching events found
# No baseline correction applied
# 0 projection items activated
# [<Figure size 700x600 with 6 Axes>, <Figure size 700x600 with 6 Axes>]

# %%
##############################################################################
# Choosing a Paradigm
# -------------------
#
# Once we have instantiated a dataset, we have to choose a paradigm. This
# object is responsible for filtering the data, epoching it, and extracting
# the labels for each epoch. Note that each dataset comes with the names of
# the paradigms to which it might be associated. It would not make sense to
# process a P300 dataset with a MI paradigm object.

print(dataset.paradigm)
# Out:
# imagery

# %%
##############################################################################
# For the example below, we will consider the paradigm associated to
# left-hand/right-hand motor imagery task, but there are other options in
# MOABB for motor imagery, P300 or SSVEP.

paradigm = LeftRightImagery()

##############################################################################
# We may check the list of all datasets available in MOABB for using with this
# paradigm (note that BNCI2014_001 is in it)

print(paradigm.datasets)
# Out:
# [<moabb.datasets.bnci.BNCI2014_001 object at 0x0000021D8881ECD0>, <moabb.datasets.bnci.BNCI2014_004 object at 0x0000021D8881EA90>, <moabb.datasets.gigadb.Cho2017 object at 0x0000021D8881E220>, <moabb.datasets.mpi_mi.GrosseWentrup2009 object at 0x0000021DEC6925B0>, <moabb.datasets.Lee2019.Lee2019_MI object at 0x0000021DECB2BC10>, <moabb.datasets.physionet_mi.PhysionetMI object at 0x0000021DE2E80E20>, <moabb.datasets.schirrmeister2017.Schirrmeister2017 object at 0x0000021DC0F10820>, <moabb.datasets.bbci_eeg_fnirs.Shin2017A object at 0x0000021DECD29370>, <moabb.datasets.Weibo2014.Weibo2014 object at 0x0000021DEB6139A0>, <moabb.datasets.Zhou2016.Zhou2016 object at 0x0000021DEB613B80>]

# %%
print(paradigm.get_data(dataset=dataset, subjects=[1]))
# Out:
# (array([[[  6.12675343,   4.80069492,   1.8937593 , ...,  -1.80963356,
#           -0.95822005,   0.10018214],
#         [  5.58056783,   3.78074325,   1.02786715, ...,  -1.32946883,
#           -0.62293255,   0.06768451],
#         [  7.43279059,   5.46171881,   2.11057866, ...,  -0.57576039,
#           -0.65376666,  -0.73565678],
#         ...,
#         [  7.465582  ,   3.39468294,  -1.15504664, ...,  -3.41820391,
#           -2.94795975,  -2.31999583],
#         [  5.00811146,   1.58727604,  -2.11582106, ...,  -3.48512891,
#           -2.69524861,  -1.68924441],
#         [  8.01582351,   4.2274779 ,  -0.1410632 , ...,  -4.097163  ,
#           -3.54158428,  -2.65380789]],
#
#        [[ -0.7702083 ,  -0.77995427,  -1.51378905, ...,  -9.44448146,
#          -11.03344346, -11.02605606],
#         [ -1.33536169,  -1.04522174,  -0.87003607, ...,  -8.77443588,
#          -10.72309939, -10.2110244 ],
#         [  0.30316772,   0.02742408,  -1.01425588, ...,  -9.24718849,
#          -11.26148117, -10.91802947],
#         ...,
#         [ -6.81387658,  -7.2220894 ,  -7.60139055, ...,  -4.96596411,
#           -4.05442771,  -1.49866564],
#         [ -7.61409517,  -7.96167406,  -7.99530206, ...,  -1.37466745,
#           -0.81559275,   0.62729322],
#         [ -5.47673387,  -6.23518637,  -6.79171496, ...,  -2.97765015,
#           -1.1596811 ,   1.93256967]],
#
#        [[ -1.24587384,  -0.75302086,  -0.36225072, ...,  -2.82992323,
#           -3.22693962,  -3.27526469],
#         [ -3.6875027 ,  -3.11582514,  -2.04405365, ...,  -6.43561707,
#           -6.54762176,  -6.21128286],
#         [ -2.38313832,  -1.5811859 ,  -0.47598582, ...,  -4.16496599,
#           -4.23749071,  -4.22788532],
#         ...,
#         [  2.07223396,   4.62636381,   6.45390081, ...,   0.69641843,
#            0.11539997,  -0.48157866],
#         [  2.07361005,   4.36518136,   5.95973951, ...,   1.45651573,
#            1.06370282,   0.51153414],
#         [  1.98842798,   4.11490232,   5.58331719, ...,  -0.45020271,
#           -1.37723913,  -1.92878689]],
#
#        ...,
#
#        [[  6.59872644,   1.70126849,  -3.90740763, ...,   0.06309507,
#           -3.70758315,  -5.4388363 ],
#         [  5.45930925,   0.36041655,  -5.16098993, ...,  -4.77204777,
#           -6.33287145,  -5.5984278 ],
#         [  5.35249801,   0.31478059,  -5.06354428, ...,  -2.03284645,
#           -4.58954058,  -5.24374835],
#         ...,
#         [  7.65164957,   3.83418892,   0.11034746, ...,  -5.77195874,
#           -6.28052776,  -5.12153758],
#         [  9.43959905,   6.35714703,   3.03514519, ...,  -4.39553285,
#           -5.84319304,  -5.76223585],
#         [  7.55321517,   3.47664737,  -0.18016193, ...,  -3.44256323,
#           -3.38210688,  -2.02006842]],
#
#        [[  3.96641492,   1.21515883,  -2.29472386, ..., -10.10421233,
#           -8.24566915,  -3.79218124],
#         [  5.80626836,   4.19384841,   0.97898905, ..., -10.42033836,
#           -8.61665788,  -3.91454851],
#         [  4.83163064,   2.55749019,  -0.72910901, ..., -10.54997353,
#           -8.18615265,  -3.08138023],
#         ...,
#         [ -0.28151212,  -5.66823632, -10.79688097, ...,  -7.55421983,
#           -7.42311755,  -5.18097336],
#         [ -2.36361714,  -7.61865795, -12.16465689, ...,  -7.11591982,
#           -6.97617845,  -4.80392449],
#         [ -1.71108701,  -7.32571295, -12.3143331 , ...,  -5.98312373,
#           -5.96200294,  -4.29930532]],
#
#        [[  0.70516928,  -1.9696218 ,  -3.28150943, ...,  -3.07774664,
#           -2.15279118,  -0.72032235],
#         [ -1.12351555,  -2.83756174,  -2.7814907 , ...,  -3.06436595,
#           -2.52954674,  -1.72025114],
#         [  0.30087488,  -2.44722873,  -3.67788679, ...,  -5.00651651,
#           -3.6493291 ,  -1.50497277],
#         ...,
#         [ -2.01612753,  -2.44827552,  -1.68194009, ...,  -8.70340222,
#           -8.03403831,  -5.99541708],
#         [ -2.65958251,  -3.76009414,  -3.63224902, ...,  -7.78353027,
#           -7.15988622,  -5.3791969 ],
#         [ -3.75229019,  -2.98075739,  -0.93224665, ...,  -7.41236337,
#           -7.49863884,  -6.62258743]]]), array(['right_hand', 'left_hand', 'left_hand', 'right_hand', 'right_hand',
#        'left_hand', 'left_hand', 'left_hand', 'right_hand', 'right_hand',
#        'left_hand', 'left_hand', 'left_hand', 'right_hand', 'left_hand',
#        'right_hand', 'right_hand', 'left_hand', 'right_hand', 'left_hand',
#        'right_hand', 'right_hand', 'right_hand', 'left_hand', 'left_hand',
#        'left_hand', 'right_hand', 'left_hand', 'left_hand', 'right_hand',
#        'left_hand', 'left_hand', 'right_hand', 'left_hand', 'right_hand',
#        'right_hand', 'left_hand', 'right_hand', 'left_hand', 'left_hand',
#        'right_hand', 'left_hand', 'right_hand', 'right_hand',
#        'right_hand', 'right_hand', 'right_hand', 'left_hand',
#        'right_hand', 'left_hand', 'left_hand', 'left_hand', 'right_hand',
#        'right_hand', 'left_hand', 'right_hand', 'left_hand', 'right_hand',
#        'left_hand', 'right_hand', 'right_hand', 'right_hand', 'left_hand',
#        'left_hand', 'right_hand', 'left_hand', 'right_hand', 'right_hand',
#        'left_hand', 'left_hand', 'right_hand', 'left_hand', 'right_hand',
#        'left_hand', 'left_hand', 'right_hand', 'left_hand', 'left_hand',
#        'left_hand', 'right_hand', 'right_hand', 'right_hand',
#        'right_hand', 'left_hand', 'right_hand', 'right_hand',
#        'right_hand', 'left_hand', 'left_hand', 'left_hand', 'left_hand',
#        'left_hand', 'right_hand', 'left_hand', 'right_hand', 'right_hand',
#        'left_hand', 'right_hand', 'left_hand', 'left_hand', 'right_hand',
#        'right_hand', 'right_hand', 'left_hand', 'right_hand',
#        'right_hand', 'right_hand', 'right_hand', 'right_hand',
#        'left_hand', 'right_hand', 'right_hand', 'left_hand', 'left_hand',
#        'left_hand', 'left_hand', 'left_hand', 'left_hand', 'right_hand',
#        'left_hand', 'left_hand', 'right_hand', 'right_hand', 'left_hand',
#        'right_hand', 'right_hand', 'right_hand', 'right_hand',
#        'right_hand', 'left_hand', 'left_hand', 'left_hand', 'left_hand',
#        'right_hand', 'right_hand', 'left_hand', 'left_hand', 'left_hand',
#        'right_hand', 'right_hand', 'left_hand', 'left_hand', 'right_hand',
#        'left_hand', 'left_hand', 'right_hand', 'right_hand', 'left_hand',
#        'right_hand', 'left_hand', 'right_hand', 'right_hand', 'left_hand',
#        'right_hand', 'left_hand', 'left_hand', 'right_hand', 'left_hand',
#        'left_hand', 'left_hand', 'left_hand', 'right_hand', 'left_hand',
#        'right_hand', 'right_hand', 'left_hand', 'right_hand',
#        'right_hand', 'right_hand', 'left_hand', 'left_hand', 'right_hand',
#        'right_hand', 'left_hand', 'left_hand', 'left_hand', 'right_hand',
#        'right_hand', 'left_hand', 'left_hand', 'left_hand', 'right_hand',
#        'left_hand', 'right_hand', 'right_hand', 'left_hand', 'right_hand',
#        'left_hand', 'right_hand', 'right_hand', 'right_hand', 'left_hand',
#        'left_hand', 'left_hand', 'right_hand', 'left_hand', 'left_hand',
#        'right_hand', 'left_hand', 'left_hand', 'right_hand', 'left_hand',
#        'right_hand', 'right_hand', 'left_hand', 'right_hand', 'left_hand',
#        'left_hand', 'right_hand', 'left_hand', 'right_hand', 'right_hand',
#        'right_hand', 'right_hand', 'right_hand', 'left_hand',
#        'right_hand', 'left_hand', 'left_hand', 'left_hand', 'right_hand',
#        'right_hand', 'left_hand', 'right_hand', 'left_hand', 'right_hand',
#        'left_hand', 'right_hand', 'right_hand', 'right_hand', 'left_hand',
#        'left_hand', 'right_hand', 'left_hand', 'right_hand', 'right_hand',
#        'left_hand', 'left_hand', 'right_hand', 'left_hand', 'right_hand',
#        'left_hand', 'left_hand', 'right_hand', 'left_hand', 'left_hand',
#        'left_hand', 'right_hand', 'right_hand', 'right_hand',
#        'right_hand', 'left_hand', 'right_hand', 'right_hand',
#        'right_hand', 'left_hand', 'left_hand', 'left_hand', 'left_hand',
#        'left_hand', 'right_hand', 'left_hand', 'right_hand', 'right_hand',
#        'left_hand', 'right_hand', 'left_hand', 'left_hand', 'right_hand',
#        'right_hand', 'right_hand', 'left_hand', 'right_hand',
#        'right_hand', 'right_hand', 'right_hand', 'right_hand',
#        'left_hand', 'right_hand', 'right_hand', 'left_hand', 'left_hand',
#        'left_hand', 'left_hand', 'left_hand', 'left_hand', 'right_hand',
#        'left_hand'], dtype='<U10'),      subject session run
# 0          1  0train   0
# 1          1  0train   0
# 2          1  0train   0
# 3          1  0train   0
# 4          1  0train   0
# ..       ...     ...  ..
# 283        1   1test   5
# 284        1   1test   5
# 285        1   1test   5
# 286        1   1test   5
# 287        1   1test   5
#
# [288 rows x 3 columns])

# %%
##############################################################################
# The data from a list of subjects could be preprocessed and return as a 3D
# numpy array `X`, follow a scikit-like format with the associated `labels`.
# The `meta` object contains all information regarding the subject, the
# session and the run associated to each trial.
X, labels, meta = paradigm.get_data(dataset=dataset, subjects=[1])

# %%
##############################################################################
# Create Pipeline
# ---------------
#
# Our goal is to evaluate the performance of a given classification pipeline
# (or several of them) when it is applied to the epochs from the previously
# chosen dataset. We will consider a very simple classification pipeline in
# which the dimension of the epochs are reduced via a CSP step and then
# classified via a linear discriminant analysis.

pipeline = make_pipeline(CSP(n_components=8), LDA())

# %%
##############################################################################
# Evaluation
# ----------
#
# To evaluate the score of this pipeline, we use the `evaluation` class. When
# instantiating it, we say which paradigm we want to consider, a list with the
# datasets to analyze, and whether the scores should be recalculated each time
# we run the evaluation or if MOABB should create a cache file.
#
# Note that there are different ways of evaluating a classifier; in this
# example, we choose `WithinSessionEvaluation`, which consists of doing a
# cross-validation procedure where the training and testing partitions are from
# the same recording session of the dataset. We could have used
# `CrossSessionEvaluation`, which takes all but one session as training
# partition and the remaining one as testing partition.

evaluation = WithinSessionEvaluation(
    paradigm=paradigm,
    datasets=[dataset],
    overwrite=True,
    hdf5_path=None,
)

# %%
##############################################################################
# We obtain the results in the form of a pandas dataframe

results = evaluation.process({"csp+lda": pipeline})
# Out:
# 2024-03-02 22:27:50,981 INFO MainThread moabb.evaluations.base Processing dataset: BNCI2014-001
# BNCI2014-001-WithinSession:   0%|          | 0/3 [00:00<?, ?it/s]
# No hdf5_path provided, models will not be saved.
# 2024-03-02 22:27:57,199 INFO MainThread moabb.evaluations.base csp+lda | BNCI2014-001 | 1 | 0train: Score 0.936
# No hdf5_path provided, models will not be saved.
# 2024-03-02 22:27:59,082 INFO MainThread moabb.evaluations.base csp+lda | BNCI2014-001 | 1 | 1test: Score 0.957
# BNCI2014-001-WithinSession:  33%|███▎      | 1/3 [00:08<00:16,  8.29s/it]
# No hdf5_path provided, models will not be saved.
# 2024-03-02 22:28:04,344 INFO MainThread moabb.evaluations.base csp+lda | BNCI2014-001 | 2 | 0train: Score 0.679
# No hdf5_path provided, models will not be saved.
# 2024-03-02 22:28:06,219 INFO MainThread moabb.evaluations.base csp+lda | BNCI2014-001 | 2 | 1test: Score 0.628
# BNCI2014-001-WithinSession:  67%|██████▋   | 2/3 [00:15<00:07,  7.61s/it]
# No hdf5_path provided, models will not be saved.
# 2024-03-02 22:28:11,415 INFO MainThread moabb.evaluations.base csp+lda | BNCI2014-001 | 3 | 0train: Score 0.990
# No hdf5_path provided, models will not be saved.
# 2024-03-02 22:28:13,262 INFO MainThread moabb.evaluations.base csp+lda | BNCI2014-001 | 3 | 1test: Score 0.994
# BNCI2014-001-WithinSession: 100%|██████████| 3/3 [00:22<00:00,  7.49s/it]

# %%
##############################################################################
# The results are stored in locally, to avoid recomputing the results each time.
# It is saved in `hdf5_path` if defined or in ~/mne_data/results  otherwise.
# To export the results in CSV:

results.to_csv("./results_part2-1.csv")

##############################################################################
# To load previously obtained results saved in CSV

results = pd.read_csv("./results_part2-1.csv")

# %%
##############################################################################
# Plotting Results
# ----------------
#
# We create a figure with the seaborn package comparing the classification
# score for each subject on each session. Note that the 'subject' field from
# the `results` is given in terms of integers, but seaborn accepts only
# strings for its labeling. This is why we create the field 'subj'.

fig, ax = plt.subplots(figsize=(8, 7))
results["subj"] = results["subject"].apply(str)
sns.barplot(
    x="score", y="subj", hue="session", data=results, orient="h", palette="viridis", ax=ax
)
plt.show()
